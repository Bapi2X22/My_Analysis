# %%
import uproot
import awkward as ak
import numpy
import matplotlib.pyplot as plt

# %%
Fname = "/eos/user/b/bbapi/MC_contacts/2024_signal_samples_WH/CMSSW_15_0_15/src/WH_2024_M15.root"
with uproot.open(Fname, timeout=120) as Hfile:
    print(Hfile.keys())
    Tree = Hfile["Events"]  # can access TTrees by name
    Events = Tree.arrays(library="ak", how="zip")
# Out:
# ['tag;35', 'tag;34', 'tag;33', 'tag;32', 'tag;31', 'tag;30', 'tag;29', 'tag;28', 'tag;27', 'tag;26', 'tag;25', 'tag;24', 'tag;23', 'tag;22', 'tag;21', 'tag;20', 'tag;19', 'tag;18', 'tag;17', 'tag;16', 'tag;15', 'tag;14', 'tag;13', 'tag;12', 'tag;11', 'tag;10', 'tag;9', 'tag;8', 'tag;7', 'tag;6', 'tag;5', 'tag;4', 'tag;3', 'tag;2', 'tag;1', 'Events;1', 'LuminosityBlocks;1', 'Runs;1', 'MetaData;1', 'ParameterSets;1']

# %%
Events.Jet.fields
# Out:
# ['chMultiplicity',
#  'nConstituents',
#  'nElectrons',
#  'nMuons',
#  'nSVs',
#  'neMultiplicity',
#  'electronIdx1',
#  'electronIdx2',
#  'muonIdx1',
#  'muonIdx2',
#  'svIdx1',
#  'svIdx2',
#  'hfadjacentEtaStripsSize',
#  'hfcentralEtaStripSize',
#  'PNetRegPtRawCorr',
#  'PNetRegPtRawCorrNeutrino',
#  'PNetRegPtRawRes',
#  'UParTAK4RegPtRawCorr',
#  'UParTAK4RegPtRawCorrNeutrino',
#  'UParTAK4RegPtRawRes',
#  'UParTAK4V1RegPtRawCorr',
#  'UParTAK4V1RegPtRawCorrNeutrino',
#  'UParTAK4V1RegPtRawRes',
#  'area',
#  'btagDeepFlavB',
#  'btagDeepFlavCvB',
#  'btagDeepFlavCvL',
#  'btagDeepFlavQG',
#  'btagPNetB',
#  'btagPNetCvB',
#  'btagPNetCvL',
#  'btagPNetCvNotB',
#  'btagPNetQvG',
#  'btagPNetTauVJet',
#  'btagUParTAK4B',
#  'btagUParTAK4CvB',
#  'btagUParTAK4CvL',
#  'btagUParTAK4CvNotB',
#  'btagUParTAK4Ele',
#  'btagUParTAK4Mu',
#  'btagUParTAK4QvG',
#  'btagUParTAK4SvCB',
#  'btagUParTAK4SvUDG',
#  'btagUParTAK4TauVJet',
#  'btagUParTAK4UDG',
#  'btagUParTAK4probb',
# ...

# %%
plt.hist(ak.flatten(Events.Jet.btagUParTAK4probbb), bins=50, range=(0.5, 1), histtype="stepfilled", alpha=0.7);
