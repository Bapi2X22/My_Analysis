# %%
import awkward as ak
import numpy as np 
import matplotlib.pyplot as plt
import ROOT
from glob import glob

# %%
file_pattern = "/eos/user/b/bbapi/My_Analysis/2024_efficiency_study/Data/NTuples_2024_HDNA_presel/merged/Data_*-Data-2024*/*-Data-2024*_CAT1_merged.parquet"

files = sorted(glob(file_pattern))
Data = ak.from_parquet(files)

# %%
files
# Out:
# ['/eos/user/b/bbapi/My_Analysis/2024_efficiency_study/Data/NTuples_2024_HDNA_presel/merged/Data_EGamma-Data-2024E/EGamma-Data-2024E_CAT1_merged.parquet',
#  '/eos/user/b/bbapi/My_Analysis/2024_efficiency_study/Data/NTuples_2024_HDNA_presel/merged/Data_EGamma-Data-2024F/EGamma-Data-2024F_CAT1_merged.parquet',
#  '/eos/user/b/bbapi/My_Analysis/2024_efficiency_study/Data/NTuples_2024_HDNA_presel/merged/Data_Muon-Data-2024E/Muon-Data-2024E_CAT1_merged.parquet',
#  '/eos/user/b/bbapi/My_Analysis/2024_efficiency_study/Data/NTuples_2024_HDNA_presel/merged/Data_Muon-Data-2024F/Muon-Data-2024F_CAT1_merged.parquet']

# %%
Data.fields
# Out:
# ['BDT_12',
#  'BDT_15',
#  'BDT_20',
#  'BDT_25',
#  'BDT_30',
#  'BDT_35',
#  'BDT_40',
#  'BDT_45',
#  'BDT_50',
#  'BDT_55',
#  'BDT_60',
#  'BDT_score',
#  'Njets',
#  'charge',
#  'dZ',
#  'delphi_bb',
#  'delphi_bbgg',
#  'delphi_gg',
#  'diff_first_jet_probb_probbb',
#  'dipho_pt',
#  'electron_charge',
#  'electron_eta',
#  'electron_mass',
#  'electron_phi',
#  'electron_pt',
#  'eta',
#  'event',
#  'first_jet_B',
#  'first_jet_charge',
#  'first_jet_eta',
#  'first_jet_mass',
#  'first_jet_mass_raw',
#  'first_jet_phi',
#  'first_jet_probb',
#  'first_jet_probbb',
#  'first_jet_pt',
#  'first_jet_pt_raw',
#  'fixedGridRhoAll',
#  'lepeta',
#  'leppt',
#  'lumi',
#  'mass',
#  'mass_point',
#  'muon_charge',
#  'muon_eta',
#  'muon_mass',
#  'muon_phi',
#  'muon_pt',
#  'nPV',
#  'n_bJets',
#  'pT1_by_mbb',
#  'pT1_by_mgg',
#  'pT2_by_mbb',
#  'pT2_by_mgg',
#  'phi',
#  'pholead_ScEta',
#  'pholead_charge',
#  'pholead_cutBased',
#  'pholead_ecalPFClusterIso',
# ...

# %%
Data.pholead_pt
# Out:
# <Array [39.6, 54, 43.1, 50.6, ..., 109, 19.2, 19.6, 47.7] type='293 * ?float32'>

# %%
np.min(Data.phosublead_pt)
# Out:
# 15.018184

# %%
plt.hist(Data.pholead_pt, bins=40, range=(0, 200), histtype='step', color='blue', label='Data');

# %%
plt.hist(Data.mass, bins=50, range=(0, 200), histtype='step', color='blue', label='Data');

# %%
plt.hist(Data.mass[Data.BDT_45<0.3], bins=12, range=(10, 70), histtype='step', color='blue', label='Data');

# %%
plt.hist(Data.phosublead_pt, bins=50, range=(0, 200), histtype='step', color='blue', label='Data');

# %%
plt.hist(Data.pholead_mvaID, bins=50, range=(-1, 1), histtype='step', color='blue', label='Data');
