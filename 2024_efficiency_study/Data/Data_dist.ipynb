# %%
import awkward as ak
import numpy as np 
import matplotlib.pyplot as plt
import ROOT

# %%
file_dir = "/eos/user/b/bbapi/My_Analysis/2024_efficiency_study/Data/NTuples_Data_2024_HDNA_presel_pBDT_score/merged/Data_Data-2024F/allData_CAT1_merged.parquet"
Data = ak.from_parquet(file_dir)

# %%
Data.fields
# Out:
# ['BDT_12',
#  'BDT_15',
#  'BDT_20',
#  'BDT_25',
#  'BDT_30',
#  'BDT_35',
#  'BDT_40',
#  'BDT_45',
#  'BDT_50',
#  'BDT_55',
#  'BDT_60',
#  'BDT_score',
#  'Njets',
#  'charge',
#  'dZ',
#  'delphi_bb',
#  'delphi_bbgg',
#  'delphi_gg',
#  'diff_first_jet_probb_probbb',
#  'dipho_pt',
#  'electron_charge',
#  'electron_eta',
#  'electron_mass',
#  'electron_phi',
#  'electron_pt',
#  'eta',
#  'event',
#  'first_jet_B',
#  'first_jet_charge',
#  'first_jet_eta',
#  'first_jet_mass',
#  'first_jet_mass_raw',
#  'first_jet_phi',
#  'first_jet_probb',
#  'first_jet_probbb',
#  'first_jet_pt',
#  'first_jet_pt_raw',
#  'fixedGridRhoAll',
#  'lepeta',
#  'leppt',
#  'lumi',
#  'mass',
#  'mass_point',
#  'muon_charge',
#  'muon_eta',
#  'muon_mass',
#  'muon_phi',
#  'muon_pt',
#  'nPV',
#  'n_bJets',
#  'pT1_by_mbb',
#  'pT1_by_mgg',
#  'pT2_by_mbb',
#  'pT2_by_mgg',
#  'phi',
#  'pholead_ScEta',
#  'pholead_charge',
#  'pholead_cutBased',
#  'pholead_ecalPFClusterIso',
# ...

# %%
Data.pholead_pt
# Out:
# <Array [67.7, 35.5, 19.5, 99.1, ..., 25.9, 35.9, 101] type='90 * ?float32'>

# %%
plt.hist(Data.pholead_pt, bins=50, range=(0, 200), histtype='step', color='blue', label='Data');

# %%
plt.hist(Data.mass, bins=50, range=(0, 200), histtype='step', color='blue', label='Data');

# %%
plt.hist(Data.mass, bins=12, range=(10, 70), histtype='step', color='blue', label='Data');

# %%
plt.hist(Data.phosublead_pt, bins=50, range=(0, 200), histtype='step', color='blue', label='Data');

# %%
plt.hist(Data.pholead_mvaID, bins=50, range=(-1, 1), histtype='step', color='blue', label='Data');
