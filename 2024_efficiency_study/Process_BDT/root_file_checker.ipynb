# %%
import uproot

# %%
f = uproot.open("merged_bkg_withMass.root")
f_sig = uproot.open("merged_signal.root")

# %%
f.keys()
tree = f["DiphotonTree"]
tree_sig = f_sig["DiphotonTree"]

# %%
tree.keys()
# Out:
# ['pholead_cutBased',
#  'pholead_electronVeto',
#  'pholead_hasConversionTracks',
#  'pholead_isScEtaEB',
#  'pholead_isScEtaEE',
#  'pholead_mvaID_WP80',
#  'pholead_mvaID_WP90',
#  'pholead_pixelSeed',
#  'pholead_seedGain',
#  'pholead_electronIdx',
#  'pholead_jetIdx',
#  'pholead_seediEtaOriX',
#  'pholead_seediPhiOriY',
#  'pholead_vidNestedWPBitmap',
#  'pholead_ecalPFClusterIso',
#  'pholead_energyErr',
#  'pholead_energyRaw',
#  'pholead_esEffSigmaRR',
#  'pholead_esEnergyOverRawE',
#  'pholead_eta',
#  'pholead_etaWidth',
#  'pholead_haloTaggerMVAVal',
#  'pholead_hcalPFClusterIso',
#  'pholead_hoe',
#  'pholead_hoe_PUcorr',
#  'pholead_hoe_Tower',
#  'pholead_mvaID',
#  'pholead_pfChargedIso',
#  'pholead_pfChargedIsoPFPV',
#  'pholead_pfChargedIsoWorstVtx',
#  'pholead_pfPhoIso03',
#  'pholead_pfRelIso03_all_quadratic',
#  'pholead_pfRelIso03_chg_quadratic',
#  'pholead_phi',
#  'pholead_phiWidth',
#  'pholead_r9',
#  'pholead_s4',
#  'pholead_sieie',
#  'pholead_sieip',
#  'pholead_sipip',
#  'pholead_superclusterEta',
#  'pholead_trkSumPtHollowConeDR03',
#  'pholead_trkSumPtSolidConeDR04',
#  'pholead_x_calo',
#  'pholead_y_calo',
#  'pholead_z_calo',
#  'pholead_genPartFlav',
#  'pholead_genPartIdx',
#  'pholead_electronIdxG',
#  'pholead_genPartIdxG',
#  'pholead_jetIdxG',
#  'pholead_ScEta',
#  'pholead_pt_raw',
#  'pholead_rho_smear',
#  'pholead_pt',
#  'pholead_charge',
#  'phosublead_cutBased',
#  'phosublead_electronVeto',
#  'phosublead_hasConversionTracks',
#  'phosublead_isScEtaEB',
#  'phosublead_isScEtaEE',
#  'phosublead_mvaID_WP80',
#  'phosublead_mvaID_WP90',
#  'phosublead_pixelSeed',
#  'phosublead_seedGain',
#  'phosublead_electronIdx',
#  'phosublead_jetIdx',
#  'phosublead_seediEtaOriX',
#  'phosublead_seediPhiOriY',
#  'phosublead_vidNestedWPBitmap',
#  'phosublead_ecalPFClusterIso',
#  'phosublead_energyErr',
#  'phosublead_energyRaw',
#  'phosublead_esEffSigmaRR',
#  'phosublead_esEnergyOverRawE',
#  'phosublead_eta',
#  'phosublead_etaWidth',
#  'phosublead_haloTaggerMVAVal',
#  'phosublead_hcalPFClusterIso',
#  'phosublead_hoe',
#  'phosublead_hoe_PUcorr',
#  'phosublead_hoe_Tower',
#  'phosublead_mvaID',
#  'phosublead_pfChargedIso',
#  'phosublead_pfChargedIsoPFPV',
#  'phosublead_pfChargedIsoWorstVtx',
#  'phosublead_pfPhoIso03',
#  'phosublead_pfRelIso03_all_quadratic',
#  'phosublead_pfRelIso03_chg_quadratic',
#  'phosublead_phi',
#  'phosublead_phiWidth',
#  'phosublead_r9',
#  'phosublead_s4',
#  'phosublead_sieie',
#  'phosublead_sieip',
#  'phosublead_sipip',
#  'phosublead_superclusterEta',
#  'phosublead_trkSumPtHollowConeDR03',
#  'phosublead_trkSumPtSolidConeDR04',
#  'phosublead_x_calo',
#  'phosublead_y_calo',
#  'phosublead_z_calo',
#  'phosublead_genPartFlav',
#  'phosublead_genPartIdx',
#  'phosublead_electronIdxG',
#  'phosublead_genPartIdxG',
#  'phosublead_jetIdxG',
#  'phosublead_ScEta',
#  'phosublead_pt_raw',
#  'phosublead_rho_smear',
#  'phosublead_pt',
#  'phosublead_charge',
#  'pt',
#  'dipho_pt',
#  'eta',
#  'phi',
#  'CMS_hgg_mass',
#  'charge',
#  'rapidity',
#  'n_bJets',
#  'first_jet_pt',
#  'first_jet_pt_raw',
#  'first_jet_eta',
#  'first_jet_phi',
#  'first_jet_mass',
#  'first_jet_mass_raw',
#  'first_jet_charge',
#  'first_jet_B',
#  'first_jet_probb',
#  'first_jet_probbb',
#  'diff_first_jet_probb_probbb',
#  'second_jet_pt',
#  'second_jet_pt_raw',
#  'second_jet_eta',
#  'second_jet_phi',
#  'second_jet_mass',
#  'second_jet_mass_raw',
#  'second_jet_charge',
#  'second_jet_B',
#  'second_jet_probb',
#  'second_jet_probbb',
#  'electron_pt',
#  'electron_eta',
#  'electron_phi',
#  'electron_mass',
#  'electron_charge',
#  'muon_pt',
#  'muon_eta',
#  'muon_phi',
#  'muon_mass',
#  'muon_charge',
#  'event',
#  'lumi',
#  'run',
#  'nPV',
#  'fixedGridRhoAll',
#  'genWeight',
#  'dZ',
#  'HTXS_Higgs_pt',
#  'HTXS_Higgs_y',
#  'HTXS_njets30',
#  'HTXS_stage_0',
#  'weight_central',
#  'event_idx',
#  'weight_nominal',
#  'weight',
#  'weight_PileupDown',
#  'weight_SF_photon_IDUp',
#  'weight_PileupUp',
#  'weight_SF_photon_IDDown',
#  'phys_wgt',
#  'process_id',
#  'evt_wgt',
#  'mass_point']

# %%
arr = tree.arrays(library="ak") 
arr_sig = tree_sig.arrays(library="ak")

# %%
arr.fields
# Out:
# ['pholead_cutBased',
#  'pholead_electronVeto',
#  'pholead_hasConversionTracks',
#  'pholead_isScEtaEB',
#  'pholead_isScEtaEE',
#  'pholead_mvaID_WP80',
#  'pholead_mvaID_WP90',
#  'pholead_pixelSeed',
#  'pholead_seedGain',
#  'pholead_electronIdx',
#  'pholead_jetIdx',
#  'pholead_seediEtaOriX',
#  'pholead_seediPhiOriY',
#  'pholead_vidNestedWPBitmap',
#  'pholead_ecalPFClusterIso',
#  'pholead_energyErr',
#  'pholead_energyRaw',
#  'pholead_esEffSigmaRR',
#  'pholead_esEnergyOverRawE',
#  'pholead_eta',
#  'pholead_etaWidth',
#  'pholead_haloTaggerMVAVal',
#  'pholead_hcalPFClusterIso',
#  'pholead_hoe',
#  'pholead_hoe_PUcorr',
#  'pholead_hoe_Tower',
#  'pholead_mvaID',
#  'pholead_pfChargedIso',
#  'pholead_pfChargedIsoPFPV',
#  'pholead_pfChargedIsoWorstVtx',
#  'pholead_pfPhoIso03',
#  'pholead_pfRelIso03_all_quadratic',
#  'pholead_pfRelIso03_chg_quadratic',
#  'pholead_phi',
#  'pholead_phiWidth',
#  'pholead_r9',
#  'pholead_s4',
#  'pholead_sieie',
#  'pholead_sieip',
#  'pholead_sipip',
#  'pholead_superclusterEta',
#  'pholead_trkSumPtHollowConeDR03',
#  'pholead_trkSumPtSolidConeDR04',
#  'pholead_x_calo',
#  'pholead_y_calo',
#  'pholead_z_calo',
#  'pholead_genPartFlav',
#  'pholead_genPartIdx',
#  'pholead_electronIdxG',
#  'pholead_genPartIdxG',
#  'pholead_jetIdxG',
#  'pholead_ScEta',
#  'pholead_pt_raw',
#  'pholead_rho_smear',
#  'pholead_pt',
#  'pholead_charge',
#  'phosublead_cutBased',
#  'phosublead_electronVeto',
#  'phosublead_hasConversionTracks',
#  'phosublead_isScEtaEB',
#  'phosublead_isScEtaEE',
#  'phosublead_mvaID_WP80',
#  'phosublead_mvaID_WP90',
#  'phosublead_pixelSeed',
#  'phosublead_seedGain',
#  'phosublead_electronIdx',
#  'phosublead_jetIdx',
#  'phosublead_seediEtaOriX',
#  'phosublead_seediPhiOriY',
#  'phosublead_vidNestedWPBitmap',
#  'phosublead_ecalPFClusterIso',
#  'phosublead_energyErr',
#  'phosublead_energyRaw',
#  'phosublead_esEffSigmaRR',
#  'phosublead_esEnergyOverRawE',
#  'phosublead_eta',
#  'phosublead_etaWidth',
#  'phosublead_haloTaggerMVAVal',
#  'phosublead_hcalPFClusterIso',
#  'phosublead_hoe',
#  'phosublead_hoe_PUcorr',
#  'phosublead_hoe_Tower',
#  'phosublead_mvaID',
#  'phosublead_pfChargedIso',
#  'phosublead_pfChargedIsoPFPV',
#  'phosublead_pfChargedIsoWorstVtx',
#  'phosublead_pfPhoIso03',
#  'phosublead_pfRelIso03_all_quadratic',
#  'phosublead_pfRelIso03_chg_quadratic',
#  'phosublead_phi',
#  'phosublead_phiWidth',
#  'phosublead_r9',
#  'phosublead_s4',
#  'phosublead_sieie',
#  'phosublead_sieip',
#  'phosublead_sipip',
#  'phosublead_superclusterEta',
#  'phosublead_trkSumPtHollowConeDR03',
#  'phosublead_trkSumPtSolidConeDR04',
#  'phosublead_x_calo',
#  'phosublead_y_calo',
#  'phosublead_z_calo',
#  'phosublead_genPartFlav',
#  'phosublead_genPartIdx',
#  'phosublead_electronIdxG',
#  'phosublead_genPartIdxG',
#  'phosublead_jetIdxG',
#  'phosublead_ScEta',
#  'phosublead_pt_raw',
#  'phosublead_rho_smear',
#  'phosublead_pt',
#  'phosublead_charge',
#  'pt',
#  'dipho_pt',
#  'eta',
#  'phi',
#  'CMS_hgg_mass',
#  'charge',
#  'rapidity',
#  'n_bJets',
#  'first_jet_pt',
#  'first_jet_pt_raw',
#  'first_jet_eta',
#  'first_jet_phi',
#  'first_jet_mass',
#  'first_jet_mass_raw',
#  'first_jet_charge',
#  'first_jet_B',
#  'first_jet_probb',
#  'first_jet_probbb',
#  'diff_first_jet_probb_probbb',
#  'second_jet_pt',
#  'second_jet_pt_raw',
#  'second_jet_eta',
#  'second_jet_phi',
#  'second_jet_mass',
#  'second_jet_mass_raw',
#  'second_jet_charge',
#  'second_jet_B',
#  'second_jet_probb',
#  'second_jet_probbb',
#  'electron_pt',
#  'electron_eta',
#  'electron_phi',
#  'electron_mass',
#  'electron_charge',
#  'muon_pt',
#  'muon_eta',
#  'muon_phi',
#  'muon_mass',
#  'muon_charge',
#  'event',
#  'lumi',
#  'run',
#  'nPV',
#  'fixedGridRhoAll',
#  'genWeight',
#  'dZ',
#  'HTXS_Higgs_pt',
#  'HTXS_Higgs_y',
#  'HTXS_njets30',
#  'HTXS_stage_0',
#  'weight_central',
#  'event_idx',
#  'weight_nominal',
#  'weight',
#  'weight_PileupDown',
#  'weight_SF_photon_IDUp',
#  'weight_PileupUp',
#  'weight_SF_photon_IDDown',
#  'phys_wgt',
#  'process_id',
#  'evt_wgt',
#  'mass_point']

# %%
arr.mass_point
# Out:
# <Array [45, 20, 50, 25, 20, 50, ..., 50, 60, 30, 15, 35] type='35714 * int32'>

# %%
arr.evt_wgt
# Out:
# <Array [3.87e-05, 7.77e-05, ..., 9.69e-05, -0.000303] type='35714 * float64'>

# %%
arr_sig.evt_wgt
# Out:
# <Array [8.3e-06, 1.48e-05, ..., 1.41e-05, 4.81e-06] type='60166 * float64'>

# %%
import awkward as ak

# %%
ak.sum(arr.evt_wgt)
# Out:
# 0.9999999999999931

# %%
ak.min(abs(arr.evt_wgt))
# Out:
# 4.804340484313191e-06

# %%
arr.fields
# Out:
# ['pholead_cutBased',
#  'pholead_electronVeto',
#  'pholead_hasConversionTracks',
#  'pholead_isScEtaEB',
#  'pholead_isScEtaEE',
#  'pholead_mvaID_WP80',
#  'pholead_mvaID_WP90',
#  'pholead_pixelSeed',
#  'pholead_seedGain',
#  'pholead_electronIdx',
#  'pholead_jetIdx',
#  'pholead_seediEtaOriX',
#  'pholead_seediPhiOriY',
#  'pholead_vidNestedWPBitmap',
#  'pholead_ecalPFClusterIso',
#  'pholead_energyErr',
#  'pholead_energyRaw',
#  'pholead_esEffSigmaRR',
#  'pholead_esEnergyOverRawE',
#  'pholead_eta',
#  'pholead_etaWidth',
#  'pholead_haloTaggerMVAVal',
#  'pholead_hcalPFClusterIso',
#  'pholead_hoe',
#  'pholead_hoe_PUcorr',
#  'pholead_hoe_Tower',
#  'pholead_mvaID',
#  'pholead_pfChargedIso',
#  'pholead_pfChargedIsoPFPV',
#  'pholead_pfChargedIsoWorstVtx',
#  'pholead_pfPhoIso03',
#  'pholead_pfRelIso03_all_quadratic',
#  'pholead_pfRelIso03_chg_quadratic',
#  'pholead_phi',
#  'pholead_phiWidth',
#  'pholead_r9',
#  'pholead_s4',
#  'pholead_sieie',
#  'pholead_sieip',
#  'pholead_sipip',
#  'pholead_superclusterEta',
#  'pholead_trkSumPtHollowConeDR03',
#  'pholead_trkSumPtSolidConeDR04',
#  'pholead_x_calo',
#  'pholead_y_calo',
#  'pholead_z_calo',
#  'pholead_genPartFlav',
#  'pholead_genPartIdx',
#  'pholead_electronIdxG',
#  'pholead_genPartIdxG',
#  'pholead_jetIdxG',
#  'pholead_ScEta',
#  'pholead_pt_raw',
#  'pholead_rho_smear',
#  'pholead_pt',
#  'pholead_charge',
#  'phosublead_cutBased',
#  'phosublead_electronVeto',
#  'phosublead_hasConversionTracks',
#  'phosublead_isScEtaEB',
#  'phosublead_isScEtaEE',
#  'phosublead_mvaID_WP80',
#  'phosublead_mvaID_WP90',
#  'phosublead_pixelSeed',
#  'phosublead_seedGain',
#  'phosublead_electronIdx',
#  'phosublead_jetIdx',
#  'phosublead_seediEtaOriX',
#  'phosublead_seediPhiOriY',
#  'phosublead_vidNestedWPBitmap',
#  'phosublead_ecalPFClusterIso',
#  'phosublead_energyErr',
#  'phosublead_energyRaw',
#  'phosublead_esEffSigmaRR',
#  'phosublead_esEnergyOverRawE',
#  'phosublead_eta',
#  'phosublead_etaWidth',
#  'phosublead_haloTaggerMVAVal',
#  'phosublead_hcalPFClusterIso',
#  'phosublead_hoe',
#  'phosublead_hoe_PUcorr',
#  'phosublead_hoe_Tower',
#  'phosublead_mvaID',
#  'phosublead_pfChargedIso',
#  'phosublead_pfChargedIsoPFPV',
#  'phosublead_pfChargedIsoWorstVtx',
#  'phosublead_pfPhoIso03',
#  'phosublead_pfRelIso03_all_quadratic',
#  'phosublead_pfRelIso03_chg_quadratic',
#  'phosublead_phi',
#  'phosublead_phiWidth',
#  'phosublead_r9',
#  'phosublead_s4',
#  'phosublead_sieie',
#  'phosublead_sieip',
#  'phosublead_sipip',
#  'phosublead_superclusterEta',
#  'phosublead_trkSumPtHollowConeDR03',
#  'phosublead_trkSumPtSolidConeDR04',
#  'phosublead_x_calo',
#  'phosublead_y_calo',
#  'phosublead_z_calo',
#  'phosublead_genPartFlav',
#  'phosublead_genPartIdx',
#  'phosublead_electronIdxG',
#  'phosublead_genPartIdxG',
#  'phosublead_jetIdxG',
#  'phosublead_ScEta',
#  'phosublead_pt_raw',
#  'phosublead_rho_smear',
#  'phosublead_pt',
#  'phosublead_charge',
#  'pt',
#  'dipho_pt',
#  'eta',
#  'phi',
#  'CMS_hgg_mass',
#  'charge',
#  'rapidity',
#  'n_bJets',
#  'first_jet_pt',
#  'first_jet_pt_raw',
#  'first_jet_eta',
#  'first_jet_phi',
#  'first_jet_mass',
#  'first_jet_mass_raw',
#  'first_jet_charge',
#  'first_jet_B',
#  'first_jet_probb',
#  'first_jet_probbb',
#  'diff_first_jet_probb_probbb',
#  'second_jet_pt',
#  'second_jet_pt_raw',
#  'second_jet_eta',
#  'second_jet_phi',
#  'second_jet_mass',
#  'second_jet_mass_raw',
#  'second_jet_charge',
#  'second_jet_B',
#  'second_jet_probb',
#  'second_jet_probbb',
#  'electron_pt',
#  'electron_eta',
#  'electron_phi',
#  'electron_mass',
#  'electron_charge',
#  'muon_pt',
#  'muon_eta',
#  'muon_phi',
#  'muon_mass',
#  'muon_charge',
#  'event',
#  'lumi',
#  'run',
#  'nPV',
#  'fixedGridRhoAll',
#  'genWeight',
#  'dZ',
#  'HTXS_Higgs_pt',
#  'HTXS_Higgs_y',
#  'HTXS_njets30',
#  'HTXS_stage_0',
#  'weight_central',
#  'event_idx',
#  'weight_nominal',
#  'weight',
#  'weight_PileupDown',
#  'weight_SF_photon_IDUp',
#  'weight_PileupUp',
#  'weight_SF_photon_IDDown',
#  'phys_wgt',
#  'process_id',
#  'evt_wgt',
#  'mass_point']
