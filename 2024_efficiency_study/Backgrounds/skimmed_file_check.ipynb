# %%
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema
import ROOT

# %%
events.GenPart.pt*1
# Out:
# <Array [[0, 0, 137, ..., 39.8, 7.53], ...] type='46 * var * float32[paramet...'>

# %%
file = '/eos/user/b/bbapi/My_Analysis/2024_efficiency_study/Backgrounds/skimmed/TTtoLNu2Q_preselected.root'
factory = NanoEventsFactory.from_root(
    f"{file}:Events",
    schemaclass=NanoAODSchema,
)
events = factory.events()

# %%
events.fields
# Out:
# ['RawPuppiMET',
#  'SoftActivityJetNjets10',
#  'Muon',
#  'CaloMET',
#  'Electron',
#  'Photon',
#  'HLTriggerFinalPath',
#  'genWeight',
#  'Tau',
#  'RawPFMET',
#  'LowPtElectron',
#  'GenPart',
#  'SoftActivityJetNjets5',
#  'Flag',
#  'MC',
#  'IsoTrack',
#  'PSWeight',
#  'run',
#  'OtherPV',
#  'bunchCrossing',
#  'Generator',
#  'LHEScaleWeight',
#  'PFCand',
#  'SubGenJetAK8',
#  'SoftActivityJetHT5',
#  'SoftActivityJetHT',
#  'PFMET',
#  'GenMET',
#  'Rho',
#  'LHEWeight',
#  'DST',
#  'PVBS',
#  'SoftActivityJetHT10',
#  'boostedTau',
#  'DeepMETResolutionTune',
#  'Dataset',
#  'CorrT1METJet',
#  'FsrPhoton',
#  'PuppiMET',
#  'LHEPdfWeight',
#  'SoftActivityJetNjets2',
#  'Jet',
#  'SoftActivityJetHT2',
#  'TauProd',
#  'GenProton',
#  'TrigObj',
#  'LHEPart',
#  'GenVisTau',
#  'orbitNumber',
#  'TrackGenJetAK4',
#  'GenJet',
#  'GenJetAK8',
#  'SoftActivityJet',
#  'LHEReweightingWeight',
#  'FatJet',
#  'GenIsolatedPhoton',
#  'TauSpinner',
#  'L1',
#  'genTtbarId',
#  'HLT',
#  'FatJetPFCand',
#  'event',
#  'FiducialMET',
#  'SV',
#  'luminosityBlock',
#  'TrkMET',
#  'DeepMETResponseTune',
#  'SubJet',
#  'Pileup',
#  'GenDressedLepton',
#  'HLTriggerFirstPath',
#  'PV',
#  'L1simulation',
#  'GenVtx',
#  'BeamSpot',
#  'L1Reco',
#  'LHE',
#  'HTXS']

# %%
events.Photon.pt*1
# Out:
# <Array [[103, 35.6, 17.4, 14.3], ..., [...]] type='27088 * var * float32[pa...'>

# %%
events.Jet.btagUParTAK4B*1
# Out:
# <Array [[0.753, 0.0838, ..., 0.0411], ...] type='60 * var * float32[paramet...'>
